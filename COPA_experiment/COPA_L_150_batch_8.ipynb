# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import transformers
import pandas
from transformers import AutoTokenizer
from transformers import RobertaModel, RobertaConfig
from transformers import AdamW
import time
import argparse

transformers.logging.set_verbosity(40) # Turn off warning
save_dir = './result_qa'

# %% [markdown]
# ## Load Data

# %%
class TensorDataset(Dataset):
    def __init__(self, tokenized_dataset, labels):
        self.tokenized_dataset = tokenized_dataset
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.tokenized_dataset.items()}
        label = self.labels[idx]
        return item, label

    def __len__(self):
        return len(self.labels)

# %%
def load_data(dataset_dir):
  dataset = pd.read_csv(dataset_dir, delimiter='\t', names=['ID', 'sentence', 'question', '1', '2','answer'], header=0)
  dataset["label"] = dataset["answer"].astype(int) - 1

  new_sentence1_1 = []
  new_sentence1_2 = []
  new_sentence2_1 = []
  new_sentence2_2 = []
  
  for i in range(len(dataset)):
    s = dataset.iloc[i]['sentence']
    q = dataset.iloc[i]['question']
    s1 = dataset.iloc[i]['1']
    s2 = dataset.iloc[i]['2']
    lb = dataset.iloc[i]['label']

    if q == "결과":
      new_sentence1_1.append(s)
      new_sentence1_2.append(s1)  # 후보1
      new_sentence2_1.append(s)
      new_sentence2_2.append(s2)  # 후보2

    else:
      new_sentence1_1.append(s1) # 후보1 먼저
      new_sentence1_2.append(s)
      new_sentence2_1.append(s2) # 후보2 먼저 
      new_sentence2_2.append(s) 

  dataset["new_sentence1_1"] = new_sentence1_1
  dataset["new_sentence1_2"] = new_sentence1_2
  dataset["new_sentence2_1"] = new_sentence2_1
  dataset["new_sentence2_2"] = new_sentence2_2

  return dataset

# %%
def tokenized_dataset(dataset, tokenizer) :
  sentence1_1 = dataset['new_sentence1_1'].tolist()
  sentence1_2 = dataset['new_sentence1_2'].tolist()
  sentence2_1 = dataset["new_sentence2_1"].tolist()
  sentence2_2 = dataset["new_sentence2_2"].tolist()

  # 결과인 경우
  tokenized_sentences = tokenizer(
      sentence1_1,
      sentence1_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150, 
      add_special_tokens = True,
      return_token_type_ids = True
  )

  # 원인인 경우
  tokenized_sentences2 = tokenizer(
      sentence2_1,
      sentence2_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150,  
      add_special_tokens = True,
      return_token_type_ids = True
  )
  
  # Sentence 하나로 합쳐 return 하기
  for key, value in tokenized_sentences2.items() :
    tokenized_sentences[key+'2'] = value

  return tokenized_sentences

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model_type = "Roberta"
size = 'large'
model_name = f"klue/roberta-{size}"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/243k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/734k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
import pandas as pd

if size == 'base':
    batch_size = 32
else:
    batch_size = 8

base_path = '/content/drive/MyDrive/NLP_Final/'
train_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Train.tsv'))
val_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Dev.tsv'))

train_tokenized = tokenized_dataset(train_dataset, tokenizer)
val_tokenized = tokenized_dataset(val_dataset, tokenizer)

train_dataset = TensorDataset(train_tokenized, train_dataset['label'])
val_dataset = TensorDataset(val_tokenized, val_dataset['label'])
    
train_loader = DataLoader(train_dataset, batch_size=batch_size,drop_last=True, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=False, shuffle=False)

# %%
class Roberta(RobertaModel):
    def __init__(self, config, model_name):
        super(Roberta, self).__init__(config)
        self.roberta = RobertaModel.from_pretrained(model_name, config=config)
        self.hdim = config.hidden_size
        self.nclass = config.nclass
        self.classifier = nn.Linear(self.hdim, self.nclass-1)

    def forward(self, input_ids, input_ids2, attention_mask, attention_mask2, **kwargs):
        outputs = self.roberta(input_ids, attention_mask=attention_mask)
        outputs2 = self.roberta(input_ids2, attention_mask=attention_mask2)
        h = outputs[0][:, 0, :]
        h2 = outputs2[0][:, 0, :]
        logits1 = self.classifier(h)
        logits2 = self.classifier(h2)
        logits = torch.cat([logits1, logits2], dim=1)
        return logits

config = RobertaConfig.from_pretrained(model_name)
config.nclass = 2
# Out:
# Downloading:   0%|          | 0.00/547 [00:00<?, ?B/s]

# %%
def train_epoch(epoch, model, train_loader, optimizer, scheduler):
    model.train()
    total_loss = 0
    cor = 0
    n_sample = 0
    s = time.time()
    criterion = nn.CrossEntropyLoss()

    for data, target in train_loader:
        item = {key: val.to(device) for key, val in data.items()}
        target = target.to(device)

        logits = model(**item)
        loss = criterion(logits, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        with torch.no_grad():
            preds = torch.argmax(logits, dim=-1)

        total_loss += loss.item()
        cor += (preds == target).sum().item()
        n_sample += len(target)

        print(f"{cor}/{n_sample}", end='\r')

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    print(
        f"[Epoch {epoch}] Train loss: {loss_avg:.3f}, acc: {acc*100:.2f}, time: {time.time()-s:.1f}s"
    )
    return acc


def validate(epoch, model, val_loader, verbose=True):
    model.eval()
    total_loss = 0
    cor = 0
    n_sample = 0
    criterion = nn.CrossEntropyLoss()
    pred_all = []
    
    with torch.no_grad():
        for data, target in val_loader:
            item = {key: val.to(device) for key, val in data.items()}
            target = target.to(device)

            logits = model(**item)
            loss = criterion(logits, target)
            preds = torch.argmax(logits, dim=-1)
            pred_all.append(preds)

            total_loss += loss.item()
            cor += (preds == target).sum().item()
            n_sample += len(target)

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    pred_all = torch.cat(pred_all)
    
    if verbose:
        print(f"[Epoch {epoch}] Valid loss: {loss_avg:.3f}, acc: {acc*100:.2f}")
    return acc, pred_all


def train(idx, num_epochs, lr, train_loader, val_loader):
    print(f"Start trining {idx}th model")
    model = Roberta(config, model_name).to(device)
    optimizer = AdamW(model.parameters(), lr=lr)
    scheduler = transformers.get_scheduler("linear",
                                           optimizer=optimizer,
                                           num_warmup_steps=num_epochs * len(train_loader) // 10,
                                           num_training_steps=num_epochs * len(train_loader))
    best_acc = 0
    for epoch in range(num_epochs):
        train_acc = train_epoch(epoch, model, train_loader, optimizer, scheduler)
        val_acc, _ = validate(epoch, model, val_loader)
        if val_acc > best_acc:
            best_acc = val_acc

            model_to_save = model.module if hasattr(model, "module") else model
            model_to_save.save_pretrained(os.path.join(save_dir, f'{idx}'))
            
    print(f"Training finish! Best validation accuracy: {best_acc*100:.2f}\n")

# %%
lr = 8e-6
num_epochs = 10

# %%
for i in range(10):
    train(i, num_epochs, lr, train_loader, val_loader)
# Out:
# Start trining 0th model
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# [Epoch 0] Train loss: 0.071, acc: 66.46, time: 108.6s
# [Epoch 0] Valid loss: 0.039, acc: 88.60
# [Epoch 1] Train loss: 0.031, acc: 90.19, time: 108.2s
# [Epoch 1] Valid loss: 0.034, acc: 89.80
# [Epoch 2] Train loss: 0.011, acc: 96.82, time: 108.2s
# [Epoch 2] Valid loss: 0.043, acc: 89.80
# [Epoch 3] Train loss: 0.004, acc: 98.77, time: 108.1s
# [Epoch 3] Valid loss: 0.051, acc: 90.80
# [Epoch 4] Train loss: 0.003, acc: 99.38, time: 108.2s
# [Epoch 4] Valid loss: 0.056, acc: 90.60
# [Epoch 5] Train loss: 0.001, acc: 99.71, time: 108.1s
# [Epoch 5] Valid loss: 0.055, acc: 90.60
# [Epoch 6] Train loss: 0.001, acc: 99.74, time: 108.1s
# [Epoch 6] Valid loss: 0.059, acc: 90.60
# [Epoch 7] Train loss: 0.001, acc: 99.77, time: 108.1s
# [Epoch 7] Valid loss: 0.058, acc: 90.60
# [Epoch 8] Train loss: 0.001, acc: 99.77, time: 108.1s
# [Epoch 8] Valid loss: 0.063, acc: 89.80
# [Epoch 9] Train loss: 0.000, acc: 99.87, time: 108.1s
# [Epoch 9] Valid loss: 0.062, acc: 89.40
# Training finish! Best validation accuracy: 90.80
#
# Start trining 1th model
# [Epoch 0] Train loss: 0.071, acc: 65.97, time: 108.3s
# [Epoch 0] Valid loss: 0.039, acc: 86.80
# [Epoch 1] Train loss: 0.034, acc: 89.19, time: 108.1s
# [Epoch 1] Valid loss: 0.036, acc: 89.20
# [Epoch 2] Train loss: 0.011, acc: 96.92, time: 108.1s
# [Epoch 2] Valid loss: 0.044, acc: 91.00
# [Epoch 3] Train loss: 0.005, acc: 98.83, time: 108.1s
# [Epoch 3] Valid loss: 0.043, acc: 92.00
# [Epoch 4] Train loss: 0.002, acc: 99.48, time: 108.1s
# [Epoch 4] Valid loss: 0.046, acc: 91.20
# [Epoch 5] Train loss: 0.002, acc: 99.61, time: 108.2s
# [Epoch 5] Valid loss: 0.051, acc: 91.80
# [Epoch 6] Train loss: 0.001, acc: 99.68, time: 108.2s
# [Epoch 6] Valid loss: 0.053, acc: 91.80
# [Epoch 7] Train loss: 0.001, acc: 99.90, time: 108.2s
# [Epoch 7] Valid loss: 0.051, acc: 91.80
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 108.2s
# [Epoch 8] Valid loss: 0.053, acc: 92.00
# [Epoch 9] Train loss: 0.001, acc: 99.84, time: 108.2s
# [Epoch 9] Valid loss: 0.054, acc: 92.00
# Training finish! Best validation accuracy: 92.00
#
# Start trining 2th model
# [Epoch 0] Train loss: 0.073, acc: 64.97, time: 108.4s
# [Epoch 0] Valid loss: 0.038, acc: 88.00
# [Epoch 1] Train loss: 0.036, acc: 87.82, time: 108.2s
# [Epoch 1] Valid loss: 0.032, acc: 91.40
# [Epoch 2] Train loss: 0.013, acc: 96.23, time: 108.2s
# [Epoch 2] Valid loss: 0.041, acc: 92.20
# [Epoch 3] Train loss: 0.005, acc: 98.44, time: 108.2s
# [Epoch 3] Valid loss: 0.043, acc: 92.80
# [Epoch 4] Train loss: 0.003, acc: 99.29, time: 108.2s
# [Epoch 4] Valid loss: 0.047, acc: 91.80
# [Epoch 5] Train loss: 0.002, acc: 99.32, time: 108.2s
# [Epoch 5] Valid loss: 0.051, acc: 91.20
# [Epoch 6] Train loss: 0.002, acc: 99.58, time: 108.2s
# [Epoch 6] Valid loss: 0.047, acc: 91.80
# [Epoch 7] Train loss: 0.001, acc: 99.71, time: 108.2s
# [Epoch 7] Valid loss: 0.052, acc: 91.60
# [Epoch 8] Train loss: 0.001, acc: 99.84, time: 108.2s
# [Epoch 8] Valid loss: 0.052, acc: 91.20
# [Epoch 9] Train loss: 0.000, acc: 99.94, time: 108.2s
# [Epoch 9] Valid loss: 0.052, acc: 91.20
# Training finish! Best validation accuracy: 92.80
#
# Start trining 3th model
# [Epoch 0] Train loss: 0.070, acc: 67.63, time: 108.6s
# [Epoch 0] Valid loss: 0.037, acc: 89.80
# [Epoch 1] Train loss: 0.032, acc: 89.29, time: 108.2s
# [Epoch 1] Valid loss: 0.036, acc: 91.40
# [Epoch 2] Train loss: 0.010, acc: 96.98, time: 108.3s
# [Epoch 2] Valid loss: 0.044, acc: 91.20
# [Epoch 3] Train loss: 0.006, acc: 98.31, time: 108.2s
# [Epoch 3] Valid loss: 0.049, acc: 91.40
# [Epoch 4] Train loss: 0.003, acc: 99.19, time: 108.2s
# [Epoch 4] Valid loss: 0.060, acc: 90.40
# [Epoch 5] Train loss: 0.002, acc: 99.68, time: 108.2s
# [Epoch 5] Valid loss: 0.059, acc: 91.20
# [Epoch 6] Train loss: 0.001, acc: 99.77, time: 108.2s
# [Epoch 6] Valid loss: 0.058, acc: 91.60
# [Epoch 7] Train loss: 0.001, acc: 99.97, time: 108.2s
# [Epoch 7] Valid loss: 0.062, acc: 91.80
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 108.2s
# [Epoch 8] Valid loss: 0.063, acc: 91.40
# [Epoch 9] Train loss: 0.001, acc: 99.90, time: 108.1s
# [Epoch 9] Valid loss: 0.061, acc: 91.40
# Training finish! Best validation accuracy: 91.80
#
# Start trining 4th model
# [Epoch 0] Train loss: 0.070, acc: 67.34, time: 108.4s
# [Epoch 0] Valid loss: 0.044, acc: 87.00
# [Epoch 1] Train loss: 0.034, acc: 89.03, time: 108.1s
# [Epoch 1] Valid loss: 0.036, acc: 90.00
# [Epoch 2] Train loss: 0.012, acc: 96.69, time: 108.1s
# [Epoch 2] Valid loss: 0.042, acc: 91.00
# [Epoch 3] Train loss: 0.005, acc: 98.60, time: 108.1s
# [Epoch 3] Valid loss: 0.054, acc: 91.60
# [Epoch 4] Train loss: 0.003, acc: 99.51, time: 108.1s
# [Epoch 4] Valid loss: 0.047, acc: 90.40
# [Epoch 5] Train loss: 0.002, acc: 99.61, time: 108.1s
# [Epoch 5] Valid loss: 0.053, acc: 91.20
# [Epoch 6] Train loss: 0.001, acc: 99.74, time: 108.1s
# [Epoch 6] Valid loss: 0.062, acc: 90.60
# [Epoch 7] Train loss: 0.001, acc: 99.84, time: 108.1s
# [Epoch 7] Valid loss: 0.053, acc: 91.00
# [Epoch 8] Train loss: 0.001, acc: 99.81, time: 108.1s
# [Epoch 8] Valid loss: 0.056, acc: 90.80
# [Epoch 9] Train loss: 0.001, acc: 99.84, time: 108.1s
# [Epoch 9] Valid loss: 0.057, acc: 91.20
# Training finish! Best validation accuracy: 91.60
#
# Start trining 5th model
# [Epoch 0] Train loss: 0.070, acc: 66.79, time: 108.3s
# [Epoch 0] Valid loss: 0.039, acc: 89.40
# [Epoch 1] Train loss: 0.031, acc: 89.61, time: 108.1s
# [Epoch 1] Valid loss: 0.033, acc: 91.20
# [Epoch 2] Train loss: 0.011, acc: 96.82, time: 108.1s
# [Epoch 2] Valid loss: 0.039, acc: 92.00
# [Epoch 3] Train loss: 0.004, acc: 99.03, time: 108.1s
# [Epoch 3] Valid loss: 0.049, acc: 91.20
# [Epoch 4] Train loss: 0.003, acc: 99.38, time: 108.1s
# [Epoch 4] Valid loss: 0.043, acc: 91.00
# [Epoch 5] Train loss: 0.002, acc: 99.45, time: 108.1s
# [Epoch 5] Valid loss: 0.044, acc: 90.60
# [Epoch 6] Train loss: 0.001, acc: 99.71, time: 108.1s
# [Epoch 6] Valid loss: 0.051, acc: 90.80
# [Epoch 7] Train loss: 0.001, acc: 99.90, time: 108.1s
# [Epoch 7] Valid loss: 0.050, acc: 91.20
# [Epoch 8] Train loss: 0.001, acc: 99.87, time: 108.1s
# [Epoch 8] Valid loss: 0.051, acc: 91.00
# [Epoch 9] Train loss: 0.001, acc: 99.87, time: 108.1s
# [Epoch 9] Valid loss: 0.050, acc: 91.20
# Training finish! Best validation accuracy: 92.00
#
# Start trining 6th model
# [Epoch 0] Train loss: 0.069, acc: 67.01, time: 108.4s
# [Epoch 0] Valid loss: 0.038, acc: 88.40
# [Epoch 1] Train loss: 0.030, acc: 90.68, time: 108.1s
# [Epoch 1] Valid loss: 0.034, acc: 89.80
# [Epoch 2] Train loss: 0.012, acc: 96.53, time: 108.1s
# [Epoch 2] Valid loss: 0.040, acc: 89.20
# [Epoch 3] Train loss: 0.004, acc: 99.06, time: 108.1s
# [Epoch 3] Valid loss: 0.046, acc: 90.20
# [Epoch 4] Train loss: 0.003, acc: 99.35, time: 108.1s
# [Epoch 4] Valid loss: 0.049, acc: 90.60
# [Epoch 5] Train loss: 0.001, acc: 99.77, time: 108.1s
# [Epoch 5] Valid loss: 0.057, acc: 90.60
# [Epoch 6] Train loss: 0.001, acc: 99.81, time: 108.1s
# [Epoch 6] Valid loss: 0.064, acc: 90.60
# [Epoch 7] Train loss: 0.001, acc: 99.84, time: 108.1s
# [Epoch 7] Valid loss: 0.060, acc: 90.20
# [Epoch 8] Train loss: 0.000, acc: 99.90, time: 108.1s
# [Epoch 8] Valid loss: 0.061, acc: 90.20
# [Epoch 9] Train loss: 0.001, acc: 99.87, time: 108.1s
# [Epoch 9] Valid loss: 0.061, acc: 90.80
# Training finish! Best validation accuracy: 90.80
#
# Start trining 7th model
# [Epoch 0] Train loss: 0.072, acc: 66.88, time: 108.3s
# [Epoch 0] Valid loss: 0.040, acc: 87.40
# [Epoch 1] Train loss: 0.034, acc: 88.73, time: 108.1s
# [Epoch 1] Valid loss: 0.033, acc: 91.40
# [Epoch 2] Train loss: 0.012, acc: 96.56, time: 108.1s
# [Epoch 2] Valid loss: 0.046, acc: 91.20
# [Epoch 3] Train loss: 0.005, acc: 98.54, time: 108.1s
# [Epoch 3] Valid loss: 0.049, acc: 90.20
# [Epoch 4] Train loss: 0.003, acc: 99.64, time: 108.2s
# [Epoch 4] Valid loss: 0.052, acc: 91.00
# [Epoch 5] Train loss: 0.001, acc: 99.61, time: 108.1s
# [Epoch 5] Valid loss: 0.054, acc: 90.80
# [Epoch 6] Train loss: 0.001, acc: 99.81, time: 108.1s
# [Epoch 6] Valid loss: 0.056, acc: 91.20
# [Epoch 7] Train loss: 0.001, acc: 99.90, time: 108.1s
# [Epoch 7] Valid loss: 0.059, acc: 91.40
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 108.1s
# [Epoch 8] Valid loss: 0.059, acc: 91.40
# [Epoch 9] Train loss: 0.000, acc: 100.00, time: 108.1s
# [Epoch 9] Valid loss: 0.059, acc: 91.20
# Training finish! Best validation accuracy: 91.40
#
# Start trining 8th model
# [Epoch 0] Train loss: 0.069, acc: 67.73, time: 108.4s
# [Epoch 0] Valid loss: 0.041, acc: 89.40
# [Epoch 1] Train loss: 0.032, acc: 89.87, time: 108.2s
# [Epoch 1] Valid loss: 0.039, acc: 90.20
# [Epoch 2] Train loss: 0.011, acc: 96.75, time: 108.1s
# [Epoch 2] Valid loss: 0.039, acc: 90.00
# [Epoch 3] Train loss: 0.005, acc: 98.44, time: 108.1s
# [Epoch 3] Valid loss: 0.053, acc: 89.80
# [Epoch 4] Train loss: 0.003, acc: 99.29, time: 108.1s
# [Epoch 4] Valid loss: 0.053, acc: 90.80
# [Epoch 5] Train loss: 0.001, acc: 99.81, time: 108.1s
# [Epoch 5] Valid loss: 0.057, acc: 89.80
# [Epoch 6] Train loss: 0.001, acc: 99.77, time: 108.1s
# [Epoch 6] Valid loss: 0.064, acc: 89.60
# [Epoch 7] Train loss: 0.001, acc: 99.90, time: 108.1s
# [Epoch 7] Valid loss: 0.066, acc: 90.20
# [Epoch 8] Train loss: 0.000, acc: 99.97, time: 108.1s
# [Epoch 8] Valid loss: 0.067, acc: 90.40
# [Epoch 9] Train loss: 0.001, acc: 99.84, time: 108.1s
# [Epoch 9] Valid loss: 0.065, acc: 90.60
# Training finish! Best validation accuracy: 90.80
#
# Start trining 9th model
# [Epoch 0] Train loss: 0.069, acc: 67.99, time: 108.4s
# [Epoch 0] Valid loss: 0.042, acc: 87.60
# [Epoch 1] Train loss: 0.033, acc: 89.45, time: 108.1s
# [Epoch 1] Valid loss: 0.032, acc: 91.00
# [Epoch 2] Train loss: 0.012, acc: 96.30, time: 108.1s
# [Epoch 2] Valid loss: 0.039, acc: 90.20
# [Epoch 3] Train loss: 0.006, acc: 98.51, time: 108.1s
# [Epoch 3] Valid loss: 0.056, acc: 89.60
# [Epoch 4] Train loss: 0.002, acc: 99.45, time: 108.1s
# [Epoch 4] Valid loss: 0.058, acc: 90.20
# [Epoch 5] Train loss: 0.001, acc: 99.74, time: 108.1s
# [Epoch 5] Valid loss: 0.061, acc: 89.40
# [Epoch 6] Train loss: 0.001, acc: 99.74, time: 108.1s
# [Epoch 6] Valid loss: 0.056, acc: 90.40
# [Epoch 7] Train loss: 0.001, acc: 99.68, time: 108.1s
# [Epoch 7] Valid loss: 0.063, acc: 90.20
# [Epoch 8] Train loss: 0.001, acc: 99.81, time: 108.1s
# [Epoch 8] Valid loss: 0.061, acc: 91.00
# [Epoch 9] Train loss: 0.001, acc: 99.77, time: 108.1s
# [Epoch 9] Valid loss: 0.059, acc: 91.20
# Training finish! Best validation accuracy: 91.20

# %%
def validate_ensemble(val_loader, answer, idx_max=10):
    pred_ensemble = []
    for idx in range(idx_max):
        model = Roberta.from_pretrained(os.path.join(save_dir, f'{idx}'), model_name)
        model.to(device)
        acc, pred_all = validate('best', model, val_loader, verbose=False)
        print(f"Load {idx}th model (acc: {acc*100:.2f})")
        if acc >= 0.85:
            pred_ensemble.append(pred_all)
        
    pred_ensemble = torch.stack(pred_ensemble, dim=-1).float()
    pred_ensemble = (pred_ensemble.mean(-1) >= 0.5).long().to(answer.device)
    acc_ensemble = (pred_ensemble == answer).sum() / len(answer)
    print(f"\nEnsemble accuracy: {acc_ensemble*100:.2f}")

# %%
answer = torch.tensor(val_dataset.labels)
validate_ensemble(val_loader, answer, idx_max=10)
# Out:
# Load 0th model (acc: 90.80)
# Load 1th model (acc: 92.00)
# Load 2th model (acc: 92.80)
# Load 3th model (acc: 91.80)
# Load 4th model (acc: 91.60)
# Load 5th model (acc: 92.00)
# Load 6th model (acc: 90.80)
# Load 7th model (acc: 91.40)
# Load 8th model (acc: 90.80)
# Load 9th model (acc: 91.20)
#
# Ensemble accuracy: 92.40
