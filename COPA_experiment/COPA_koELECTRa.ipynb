# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import transformers
import pandas
from transformers import AutoTokenizer
from transformers import RobertaModel, RobertaConfig
from transformers import AdamW
import time
from transformers import ElectraConfig, ElectraModel
import argparse

transformers.logging.set_verbosity(40) # Turn off warning

# %%
save_dir = './result_qa'

# %% [markdown]
# ## Load Data
# - '원인', '결과' 삭제
# - max_length : 150 > 100

# %%
class TensorDataset(Dataset):
    def __init__(self, tokenized_dataset, labels):
        self.tokenized_dataset = tokenized_dataset
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.tokenized_dataset.items()}
        label = self.labels[idx]
        return item, label

    def __len__(self):
        return len(self.labels)

# %%
def load_data(dataset_dir):
  dataset = pd.read_csv(dataset_dir, delimiter='\t', names=['ID', 'sentence', 'question', '1', '2','answer'], header=0)
  dataset["label"] = dataset["answer"].astype(int) - 1

  new_sentence1_1 = []
  new_sentence1_2 = []
  new_sentence2_1 = []
  new_sentence2_2 = []
  
  for i in range(len(dataset)):
    s = dataset.iloc[i]['sentence']
    q = dataset.iloc[i]['question']
    s1 = dataset.iloc[i]['1']
    s2 = dataset.iloc[i]['2']
    lb = dataset.iloc[i]['label']

    if q == "결과":
      new_sentence1_1.append('[결과]'+s)
      new_sentence1_2.append(s1)  # 후보1
      new_sentence2_1.append('[결과]'+s)
      new_sentence2_2.append(s2)  # 후보2

    else:
      new_sentence1_1.append("[원인]" + s1) # 후보1 먼저
      new_sentence1_2.append(s)
      new_sentence2_1.append("[원인]" + s2) # 후보2 먼저 
      new_sentence2_2.append(s) 

  dataset["new_sentence1_1"] = new_sentence1_1
  dataset["new_sentence1_2"] = new_sentence1_2
  dataset["new_sentence2_1"] = new_sentence2_1
  dataset["new_sentence2_2"] = new_sentence2_2

  return dataset

# %%
def tokenized_dataset(dataset, tokenizer) :
  sentence1_1 = dataset['new_sentence1_1'].tolist()
  sentence1_2 = dataset['new_sentence1_2'].tolist()
  sentence2_1 = dataset["new_sentence2_1"].tolist()
  sentence2_2 = dataset["new_sentence2_2"].tolist()

  # 결과인 경우
  tokenized_sentences = tokenizer(
      sentence1_1,
      sentence1_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150, 
      add_special_tokens = True,
      return_token_type_ids = True
  )

  # 원인인 경우
  tokenized_sentences2 = tokenizer(
      sentence2_1,
      sentence2_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150,  
      add_special_tokens = True,
      return_token_type_ids = True
  )
  
  # Sentence 하나로 합쳐 return 하기
  for key, value in tokenized_sentences2.items() :
    tokenized_sentences[key+'2'] = value

  return tokenized_sentences

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model_type = "Electra"
#size = 'large'
#model_name = f"klue/roberta-{size}"
model_name = f"monologg/koelectra-base-v3-discriminator"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/467 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/257k [00:00<?, ?B/s]

# %%
import pandas as pd

# if size == 'base':
#     batch_size = 16
# else:
#     batch_size = 5

batch_size = 16

base_path = '/content/drive/MyDrive/NLP_Final/'
train_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Train.tsv'))
val_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Dev.tsv'))

train_tokenized = tokenized_dataset(train_dataset, tokenizer)
val_tokenized = tokenized_dataset(val_dataset, tokenizer)

train_dataset = TensorDataset(train_tokenized, train_dataset['label'])
val_dataset = TensorDataset(val_tokenized, val_dataset['label'])
    
train_loader = DataLoader(train_dataset, batch_size=batch_size,drop_last=True, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=False, shuffle=False)

# %%
# 데이터 예시
tokenizer.decode(train_tokenized['input_ids'][0])
# Out:
# '[CLS] 이퀄라이저로 저음 음역대 소리 크기를 키웠다. [SEP] 베이스 소리가 잘 들리게 되었다. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD]'

# %%
# 데이터 예시
tokenizer.decode(train_tokenized['input_ids2'][0])
# Out:
# '[CLS] 이퀄라이저로 저음 음역대 소리 크기를 키웠다. [SEP] 베이스 소리가 들리지 않게 되었다. [SEP] [PAD] [PAD] [PAD] [PAD]'

# %% [markdown]
# ## Load pretrained model
# - 모델은 monologg koelectra-base-v3-discriminator를 사용하였습니다. (https://github.com/monologg/KoELECTRA)
# - cls token에 해당하는 hidden feature에 linear classifier를 추가했습니다.

# %%
class Electra(ElectraModel):
    # Add classification layer to Roberta model
    def __init__(self, config, model_name):
        super(Electra, self).__init__(config)
        self.electra = ElectraModel.from_pretrained(model_name, config=config)
        self.hdim = config.hidden_size
        self.nclass = config.nclass
        self.classifier = nn.Linear(self.hdim, self.nclass-1)

    def forward(self, input_ids, input_ids2, attention_mask, attention_mask2, **kwargs):
        outputs = self.electra(input_ids, attention_mask=attention_mask)
        outputs2 = self.electra(input_ids2, attention_mask=attention_mask2)
        h = outputs[0][:, 0, :]
        h2 = outputs2[0][:, 0, :]
        logits1 = self.classifier(h)
        logits2 = self.classifier(h2)
        logits = torch.cat([logits1, logits2], dim=1)
        return logits

config = ElectraConfig.from_pretrained(model_name)
config.nclass = 2

# %% [markdown]
# ## Finetune Model

# %%
def train_epoch(epoch, model, train_loader, optimizer, scheduler):
    model.train()
    total_loss = 0
    cor = 0
    n_sample = 0
    s = time.time()
    criterion = nn.CrossEntropyLoss()

    for data, target in train_loader:
        item = {key: val.to(device) for key, val in data.items()}
        target = target.to(device)

        logits = model(**item)
        loss = criterion(logits, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        with torch.no_grad():
            preds = torch.argmax(logits, dim=-1)

        total_loss += loss.item()
        cor += (preds == target).sum().item()
        n_sample += len(target)

        print(f"{cor}/{n_sample}", end='\r')

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    print(
        f"[Epoch {epoch}] Train loss: {loss_avg:.3f}, acc: {acc*100:.2f}, time: {time.time()-s:.1f}s"
    )
    return acc


def validate(epoch, model, val_loader, verbose=True):
    model.eval()
    total_loss = 0
    cor = 0
    n_sample = 0
    criterion = nn.CrossEntropyLoss()
    pred_all = []
    
    with torch.no_grad():
        for data, target in val_loader:
            item = {key: val.to(device) for key, val in data.items()}
            target = target.to(device)

            logits = model(**item)
            loss = criterion(logits, target)
            preds = torch.argmax(logits, dim=-1)
            pred_all.append(preds)

            total_loss += loss.item()
            cor += (preds == target).sum().item()
            n_sample += len(target)

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    pred_all = torch.cat(pred_all)
    
    if verbose:
        print(f"[Epoch {epoch}] Valid loss: {loss_avg:.3f}, acc: {acc*100:.2f}")
    return acc, pred_all


def train(idx, num_epochs, lr, train_loader, val_loader):
    print(f"Start trining {idx}th model")
    model = Electra(config, model_name).to(device)
    optimizer = AdamW(model.parameters(), lr=lr)
    scheduler = transformers.get_scheduler("linear",
                                           optimizer=optimizer,
                                           num_warmup_steps=num_epochs * len(train_loader) // 10,
                                           num_training_steps=num_epochs * len(train_loader))
    best_acc = 0
    for epoch in range(num_epochs):
        train_acc = train_epoch(epoch, model, train_loader, optimizer, scheduler)
        val_acc, _ = validate(epoch, model, val_loader)
        if val_acc > best_acc:
            best_acc = val_acc

            model_to_save = model.module if hasattr(model, "module") else model
            model_to_save.save_pretrained(os.path.join(save_dir, f'{idx}'))
            
    print(f"Training finish! Best validation accuracy: {best_acc*100:.2f}\n")

# %%
lr = 8e-6
num_epochs = 10

# %%
for i in range(10):
    train(i, num_epochs, lr, train_loader, val_loader)
# Out:
# Start trining 0th model
# [Epoch 0] Train loss: 0.042, acc: 54.30, time: 26.8s
# [Epoch 0] Valid loss: 0.032, acc: 80.60
# [Epoch 1] Train loss: 0.026, acc: 82.26, time: 26.8s
# [Epoch 1] Valid loss: 0.021, acc: 86.40
# [Epoch 2] Train loss: 0.015, acc: 90.95, time: 26.7s
# [Epoch 2] Valid loss: 0.023, acc: 87.00
# [Epoch 3] Train loss: 0.010, acc: 94.24, time: 26.7s
# [Epoch 3] Valid loss: 0.023, acc: 88.60
# [Epoch 4] Train loss: 0.008, acc: 95.48, time: 26.7s
# [Epoch 4] Valid loss: 0.024, acc: 88.00
# [Epoch 5] Train loss: 0.007, acc: 96.68, time: 26.7s
# [Epoch 5] Valid loss: 0.024, acc: 87.80
# [Epoch 6] Train loss: 0.005, acc: 97.40, time: 26.7s
# [Epoch 6] Valid loss: 0.025, acc: 87.60
# [Epoch 7] Train loss: 0.004, acc: 98.05, time: 26.7s
# [Epoch 7] Valid loss: 0.026, acc: 88.60
# [Epoch 8] Train loss: 0.004, acc: 97.75, time: 26.7s
# [Epoch 8] Valid loss: 0.026, acc: 88.40
# [Epoch 9] Train loss: 0.003, acc: 98.67, time: 26.7s
# [Epoch 9] Valid loss: 0.026, acc: 88.20
# Training finish! Best validation accuracy: 88.60
#
# Start trining 1th model
# [Epoch 0] Train loss: 0.041, acc: 58.82, time: 26.8s
# [Epoch 0] Valid loss: 0.030, acc: 79.40
# [Epoch 1] Train loss: 0.024, acc: 83.59, time: 26.8s
# [Epoch 1] Valid loss: 0.022, acc: 86.60
# [Epoch 2] Train loss: 0.014, acc: 90.79, time: 26.8s
# [Epoch 2] Valid loss: 0.022, acc: 86.20
# [Epoch 3] Train loss: 0.009, acc: 94.37, time: 26.8s
# [Epoch 3] Valid loss: 0.024, acc: 86.00
# [Epoch 4] Train loss: 0.007, acc: 96.16, time: 26.7s
# [Epoch 4] Valid loss: 0.024, acc: 87.40
# [Epoch 5] Train loss: 0.005, acc: 97.20, time: 26.7s
# [Epoch 5] Valid loss: 0.024, acc: 88.00
# [Epoch 6] Train loss: 0.005, acc: 97.43, time: 26.7s
# [Epoch 5] Valid loss: 0.024, acc: 87.80
# [Epoch 6] Train loss: 0.005, acc: 97.82, time: 26.7s
# [Epoch 6] Valid loss: 0.024, acc: 88.20
# [Epoch 7] Train loss: 0.004, acc: 97.79, time: 26.7s
# [Epoch 7] Valid loss: 0.025, acc: 87.80
# [Epoch 8] Train loss: 0.004, acc: 97.98, time: 26.7s
# [Epoch 8] Valid loss: 0.025, acc: 87.40
# [Epoch 9] Train loss: 0.003, acc: 98.40, time: 26.7s
# [Epoch 9] Valid loss: 0.025, acc: 87.40
# Training finish! Best validation accuracy: 88.80
#
# Start trining 9th model
# [Epoch 0] Train loss: 0.042, acc: 57.10, time: 26.8s
# [Epoch 0] Valid loss: 0.032, acc: 81.80
# [Epoch 1] Train loss: 0.025, acc: 81.87, time: 26.7s
# [Epoch 1] Valid loss: 0.022, acc: 87.60
# [Epoch 2] Train loss: 0.015, acc: 89.97, time: 26.7s
# [Epoch 2] Valid loss: 0.021, acc: 88.00
# [Epoch 3] Train loss: 0.010, acc: 93.88, time: 26.7s
# [Epoch 3] Valid loss: 0.023, acc: 87.00
# [Epoch 4] Train loss: 0.008, acc: 95.41, time: 26.7s
# [Epoch 4] Valid loss: 0.024, acc: 86.80
# [Epoch 5] Train loss: 0.006, acc: 96.32, time: 26.7s
# [Epoch 5] Valid loss: 0.025, acc: 86.60
# [Epoch 6] Train loss: 0.006, acc: 96.88, time: 26.7s
# [Epoch 6] Valid loss: 0.024, acc: 87.20
# [Epoch 7] Train loss: 0.005, acc: 97.53, time: 26.7s
# [Epoch 7] Valid loss: 0.025, acc: 87.20
# [Epoch 8] Train loss: 0.004, acc: 98.01, time: 26.7s
# [Epoch 8] Valid loss: 0.025, acc: 87.20
# [Epoch 9] Train loss: 0.004, acc: 97.69, time: 26.7s
# [Epoch 9] Valid loss: 0.025, acc: 87.60
# Training finish! Best validation accuracy: 88.00

# %%
def validate_ensemble(val_loader, answer, idx_max=10):
    pred_ensemble = []
    for idx in range(idx_max):
        model = Electra.from_pretrained(os.path.join(save_dir, f'{idx}'), model_name)
        model.to(device)
        acc, pred_all = validate('best', model, val_loader, verbose=False)
        print(f"Load {idx}th model (acc: {acc*100:.2f})")
        if acc >= 0.85:
            pred_ensemble.append(pred_all)
        
    pred_ensemble = torch.stack(pred_ensemble, dim=-1).float()
    pred_ensemble = (pred_ensemble.mean(-1) >= 0.5).long().to(answer.device)
    acc_ensemble = (pred_ensemble == answer).sum() / len(answer)
    print(f"\nEnsemble accuracy: {acc_ensemble*100:.2f}")

# %%
answer = torch.tensor(val_dataset.labels)
validate_ensemble(val_loader, answer, idx_max=10)
# Out:
# Load 0th model (acc: 88.60)
# Load 1th model (acc: 88.00)
# Load 2th model (acc: 89.00)
# Load 3th model (acc: 88.00)
# Load 4th model (acc: 87.40)
# Load 5th model (acc: 87.80)
# Load 6th model (acc: 88.20)
# Load 7th model (acc: 87.80)
# Load 8th model (acc: 88.80)
# Load 9th model (acc: 88.00)
#
# Ensemble accuracy: 88.40
