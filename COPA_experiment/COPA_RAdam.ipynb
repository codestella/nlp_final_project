# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import transformers
import pandas
from transformers import AutoTokenizer
from transformers import RobertaModel, RobertaConfig
from transformers import AdamW
import time
import argparse

transformers.logging.set_verbosity(40) # Turn off warning
save_dir = './result_qa'

# %% [markdown]
# ## Load Data

# %%
class TensorDataset(Dataset):
    def __init__(self, tokenized_dataset, labels):
        self.tokenized_dataset = tokenized_dataset
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.tokenized_dataset.items()}
        label = self.labels[idx]
        return item, label

    def __len__(self):
        return len(self.labels)

# %%
def load_data(dataset_dir):
  dataset = pd.read_csv(dataset_dir, delimiter='\t', names=['ID', 'sentence', 'question', '1', '2','answer'], header=0)
  dataset["label"] = dataset["answer"].astype(int) - 1

  new_sentence1_1 = []
  new_sentence1_2 = []
  new_sentence2_1 = []
  new_sentence2_2 = []
  
  for i in range(len(dataset)):
    s = dataset.iloc[i]['sentence']
    q = dataset.iloc[i]['question']
    s1 = dataset.iloc[i]['1']
    s2 = dataset.iloc[i]['2']
    lb = dataset.iloc[i]['label']

    if q == "결과":
      new_sentence1_1.append(s)
      new_sentence1_2.append(s1)  # 후보1
      new_sentence2_1.append(s)
      new_sentence2_2.append(s2)  # 후보2

    else:
      new_sentence1_1.append(s1) # 후보1 먼저
      new_sentence1_2.append(s)
      new_sentence2_1.append(s2) # 후보2 먼저 
      new_sentence2_2.append(s) 

  dataset["new_sentence1_1"] = new_sentence1_1
  dataset["new_sentence1_2"] = new_sentence1_2
  dataset["new_sentence2_1"] = new_sentence2_1
  dataset["new_sentence2_2"] = new_sentence2_2

  return dataset

# %%
def tokenized_dataset(dataset, tokenizer) :
  sentence1_1 = dataset['new_sentence1_1'].tolist()
  sentence1_2 = dataset['new_sentence1_2'].tolist()
  sentence2_1 = dataset["new_sentence2_1"].tolist()
  sentence2_2 = dataset["new_sentence2_2"].tolist()

  # 결과인 경우
  tokenized_sentences = tokenizer(
      sentence1_1,
      sentence1_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150, 
      add_special_tokens = True,
      return_token_type_ids = True
  )

  # 원인인 경우
  tokenized_sentences2 = tokenizer(
      sentence2_1,
      sentence2_2,
      return_tensors  = 'pt',
      padding = True,
      truncation = True, 
      max_length = 150,  
      add_special_tokens = True,
      return_token_type_ids = True
  )
  
  # Sentence 하나로 합쳐 return 하기
  for key, value in tokenized_sentences2.items() :
    tokenized_sentences[key+'2'] = value

  return tokenized_sentences

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model_type = "Roberta"
size = 'large'
model_name = f"klue/roberta-{size}"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/243k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/734k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
import pandas as pd

if size == 'base':
    batch_size = 16
else:
    batch_size = 5

base_path = '/content/drive/MyDrive/NLP_Final/'
train_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Train.tsv'))
val_dataset = load_data(os.path.join(base_path, 'SKT_COPA_Dev.tsv'))

train_tokenized = tokenized_dataset(train_dataset, tokenizer)
val_tokenized = tokenized_dataset(val_dataset, tokenizer)

train_dataset = TensorDataset(train_tokenized, train_dataset['label'])
val_dataset = TensorDataset(val_tokenized, val_dataset['label'])
    
train_loader = DataLoader(train_dataset, batch_size=batch_size,drop_last=True, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=False, shuffle=False)

# %% [markdown]
# ## Load Pretrained Model

# %%
class Roberta(RobertaModel):
    def __init__(self, config, model_name):
        super(Roberta, self).__init__(config)
        self.roberta = RobertaModel.from_pretrained(model_name, config=config)
        self.hdim = config.hidden_size
        self.nclass = config.nclass
        self.classifier = nn.Linear(self.hdim, self.nclass-1)

    def forward(self, input_ids, input_ids2, attention_mask, attention_mask2, **kwargs):
        outputs = self.roberta(input_ids, attention_mask=attention_mask)
        outputs2 = self.roberta(input_ids2, attention_mask=attention_mask2)
        h = outputs[0][:, 0, :]
        h2 = outputs2[0][:, 0, :]
        logits1 = self.classifier(h)
        logits2 = self.classifier(h2)
        logits = torch.cat([logits1, logits2], dim=1)
        return logits

config = RobertaConfig.from_pretrained(model_name)
config.nclass = 2
# Out:
# Downloading:   0%|          | 0.00/547 [00:00<?, ?B/s]

# %% [markdown]
# ## Finetune Model

# %%
pip install torch_optimizer
# Out:
# Collecting torch_optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 522 kB/s
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch_optimizer) (1.10.0+cu111)
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch_optimizer) (3.10.0.2)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.3.0

# %%
import torch_optimizer as optim

def train_epoch(epoch, model, train_loader, optimizer, scheduler):
    model.train()
    total_loss = 0
    cor = 0
    n_sample = 0
    s = time.time()
    criterion = nn.CrossEntropyLoss()

    for data, target in train_loader:
        item = {key: val.to(device) for key, val in data.items()}
        target = target.to(device)

        logits = model(**item)
        loss = criterion(logits, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        with torch.no_grad():
            preds = torch.argmax(logits, dim=-1)

        total_loss += loss.item()
        cor += (preds == target).sum().item()
        n_sample += len(target)

        print(f"{cor}/{n_sample}", end='\r')

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    print(
        f"[Epoch {epoch}] Train loss: {loss_avg:.3f}, acc: {acc*100:.2f}, time: {time.time()-s:.1f}s"
    )
    return acc


def validate(epoch, model, val_loader, verbose=True):
    model.eval()
    total_loss = 0
    cor = 0
    n_sample = 0
    criterion = nn.CrossEntropyLoss()
    pred_all = []
    
    with torch.no_grad():
        for data, target in val_loader:
            item = {key: val.to(device) for key, val in data.items()}
            target = target.to(device)

            logits = model(**item)
            loss = criterion(logits, target)
            preds = torch.argmax(logits, dim=-1)
            pred_all.append(preds)

            total_loss += loss.item()
            cor += (preds == target).sum().item()
            n_sample += len(target)

    loss_avg = total_loss / n_sample
    acc = cor / n_sample
    pred_all = torch.cat(pred_all)
    
    if verbose:
        print(f"[Epoch {epoch}] Valid loss: {loss_avg:.3f}, acc: {acc*100:.2f}")
    return acc, pred_all


def train(idx, num_epochs, lr, train_loader, val_loader):
    print(f"Start trining {idx}th model")
    model = Roberta(config, model_name).to(device)
    optimizer = optim.RAdam(model.parameters(), lr=lr)
    scheduler = transformers.get_scheduler("linear",
                                           optimizer=optimizer,
                                           num_warmup_steps=num_epochs * len(train_loader) // 10,
                                           num_training_steps=num_epochs * len(train_loader))
    best_acc = 0
    for epoch in range(num_epochs):
        train_acc = train_epoch(epoch, model, train_loader, optimizer, scheduler)
        val_acc, _ = validate(epoch, model, val_loader)
        if val_acc > best_acc:
            best_acc = val_acc

            model_to_save = model.module if hasattr(model, "module") else model
            model_to_save.save_pretrained(os.path.join(save_dir, f'{idx}'))
            
    print(f"Training finish! Best validation accuracy: {best_acc*100:.2f}\n")

# %%
lr = 8e-6
num_epochs = 10

# %% [markdown]
# ## 학습

# %%
for i in range(10):
    train(i, num_epochs, lr, train_loader, val_loader)
# Out:
# Start trining 0th model
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# [Epoch 0] Train loss: 0.134, acc: 55.45, time: 140.0s
# [Epoch 0] Valid loss: 0.103, acc: 80.20
# [Epoch 1] Train loss: 0.070, acc: 85.03, time: 139.6s
# [Epoch 1] Valid loss: 0.051, acc: 91.60
# [Epoch 2] Train loss: 0.028, acc: 95.00, time: 139.6s
# [Epoch 2] Valid loss: 0.060, acc: 90.00
# [Epoch 3] Train loss: 0.013, acc: 97.95, time: 139.6s
# [Epoch 3] Valid loss: 0.069, acc: 91.20
# [Epoch 4] Train loss: 0.007, acc: 98.93, time: 139.6s
# [Epoch 4] Valid loss: 0.080, acc: 90.20
# [Epoch 5] Train loss: 0.003, acc: 99.48, time: 139.6s
# [Epoch 5] Valid loss: 0.088, acc: 90.20
# [Epoch 6] Train loss: 0.003, acc: 99.64, time: 139.5s
# [Epoch 6] Valid loss: 0.094, acc: 90.40
# [Epoch 7] Train loss: 0.002, acc: 99.74, time: 139.5s
# [Epoch 7] Valid loss: 0.089, acc: 90.60
# [Epoch 8] Train loss: 0.001, acc: 99.84, time: 139.6s
# [Epoch 8] Valid loss: 0.090, acc: 91.00
# [Epoch 9] Train loss: 0.001, acc: 99.81, time: 139.6s
# [Epoch 9] Valid loss: 0.090, acc: 91.00
# Training finish! Best validation accuracy: 91.60
#
# Start trining 1th model
# [Epoch 0] Train loss: 0.123, acc: 61.62, time: 139.5s
# [Epoch 0] Valid loss: 0.070, acc: 85.60
# [Epoch 1] Train loss: 0.056, acc: 87.86, time: 139.6s
# [Epoch 1] Valid loss: 0.062, acc: 91.20
# [Epoch 2] Train loss: 0.022, acc: 95.97, time: 139.6s
# [Epoch 2] Valid loss: 0.065, acc: 90.60
# [Epoch 3] Train loss: 0.010, acc: 98.34, time: 139.6s
# [Epoch 3] Valid loss: 0.069, acc: 91.40
# [Epoch 4] Train loss: 0.007, acc: 98.80, time: 139.6s
# [Epoch 4] Valid loss: 0.070, acc: 91.40
# [Epoch 5] Train loss: 0.005, acc: 99.22, time: 139.6s
# [Epoch 5] Valid loss: 0.081, acc: 90.80
# [Epoch 6] Train loss: 0.002, acc: 99.77, time: 139.6s
# [Epoch 6] Valid loss: 0.084, acc: 92.00
# [Epoch 7] Train loss: 0.002, acc: 99.64, time: 139.7s
# [Epoch 7] Valid loss: 0.087, acc: 90.80
# [Epoch 8] Train loss: 0.001, acc: 99.87, time: 139.7s
# [Epoch 8] Valid loss: 0.084, acc: 91.20
# [Epoch 9] Train loss: 0.001, acc: 99.90, time: 139.7s
# [Epoch 9] Valid loss: 0.085, acc: 91.60
# Training finish! Best validation accuracy: 92.00
#
# Start trining 2th model
# [Epoch 0] Train loss: 0.129, acc: 58.60, time: 140.3s
# [Epoch 0] Valid loss: 0.071, acc: 85.80
# [Epoch 1] Train loss: 0.062, acc: 86.72, time: 139.7s
# [Epoch 1] Valid loss: 0.056, acc: 90.00
# [Epoch 2] Train loss: 0.022, acc: 95.91, time: 139.7s
# [Epoch 2] Valid loss: 0.071, acc: 91.00
# [Epoch 3] Train loss: 0.008, acc: 98.70, time: 139.7s
# [Epoch 3] Valid loss: 0.084, acc: 90.00
# [Epoch 4] Train loss: 0.006, acc: 99.16, time: 139.7s
# [Epoch 4] Valid loss: 0.084, acc: 90.20
# [Epoch 5] Train loss: 0.005, acc: 99.35, time: 139.7s
# [Epoch 5] Valid loss: 0.085, acc: 91.00
# [Epoch 6] Train loss: 0.004, acc: 99.58, time: 139.7s
# [Epoch 6] Valid loss: 0.085, acc: 91.00
# [Epoch 7] Train loss: 0.003, acc: 99.68, time: 139.7s
# [Epoch 7] Valid loss: 0.085, acc: 90.80
# [Epoch 8] Train loss: 0.001, acc: 99.94, time: 139.6s
# [Epoch 8] Valid loss: 0.091, acc: 91.80
# [Epoch 9] Train loss: 0.001, acc: 99.90, time: 139.7s
# [Epoch 9] Valid loss: 0.090, acc: 91.60
# Training finish! Best validation accuracy: 91.80
#
# Start trining 3th model
# [Epoch 0] Train loss: 0.123, acc: 61.72, time: 139.8s
# [Epoch 0] Valid loss: 0.070, acc: 85.80
# [Epoch 1] Train loss: 0.058, acc: 88.15, time: 139.7s
# [Epoch 1] Valid loss: 0.057, acc: 89.20
# [Epoch 2] Train loss: 0.023, acc: 95.45, time: 139.6s
# [Epoch 2] Valid loss: 0.067, acc: 90.40
# [Epoch 3] Train loss: 0.009, acc: 98.31, time: 139.7s
# [Epoch 3] Valid loss: 0.079, acc: 91.20
# [Epoch 4] Train loss: 0.005, acc: 98.99, time: 139.7s
# [Epoch 4] Valid loss: 0.077, acc: 90.20
# [Epoch 5] Train loss: 0.004, acc: 99.42, time: 139.7s
# [Epoch 5] Valid loss: 0.094, acc: 89.80
# [Epoch 6] Train loss: 0.002, acc: 99.87, time: 139.7s
# [Epoch 6] Valid loss: 0.093, acc: 90.40
# [Epoch 7] Train loss: 0.002, acc: 99.58, time: 139.7s
# [Epoch 7] Valid loss: 0.091, acc: 90.80
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 139.7s
# [Epoch 8] Valid loss: 0.091, acc: 90.80
# [Epoch 9] Train loss: 0.001, acc: 99.94, time: 139.7s
# [Epoch 9] Valid loss: 0.094, acc: 91.00
# Training finish! Best validation accuracy: 91.20
#
# Start trining 4th model
# [Epoch 0] Train loss: 0.122, acc: 60.55, time: 140.0s
# [Epoch 0] Valid loss: 0.073, acc: 84.40
# [Epoch 1] Train loss: 0.057, acc: 88.77, time: 139.7s
# [Epoch 1] Valid loss: 0.056, acc: 90.80
# [Epoch 2] Train loss: 0.022, acc: 96.14, time: 139.7s
# [Epoch 2] Valid loss: 0.068, acc: 91.20
# [Epoch 3] Train loss: 0.009, acc: 98.44, time: 139.7s
# [Epoch 3] Valid loss: 0.084, acc: 91.00
# [Epoch 4] Train loss: 0.007, acc: 98.70, time: 139.7s
# [Epoch 4] Valid loss: 0.083, acc: 90.20
# [Epoch 5] Train loss: 0.004, acc: 99.29, time: 139.7s
# [Epoch 5] Valid loss: 0.092, acc: 90.80
# [Epoch 6] Train loss: 0.002, acc: 99.71, time: 139.7s
# [Epoch 6] Valid loss: 0.088, acc: 90.80
# [Epoch 7] Train loss: 0.001, acc: 99.84, time: 139.7s
# [Epoch 7] Valid loss: 0.092, acc: 91.20
# [Epoch 8] Train loss: 0.001, acc: 99.81, time: 139.7s
# [Epoch 8] Valid loss: 0.093, acc: 91.00
# [Epoch 9] Train loss: 0.001, acc: 99.90, time: 139.7s
# [Epoch 9] Valid loss: 0.093, acc: 91.00
# Training finish! Best validation accuracy: 91.20
#
# Start trining 5th model
# [Epoch 0] Train loss: 0.123, acc: 61.07, time: 139.9s
# [Epoch 0] Valid loss: 0.062, acc: 89.60
# [Epoch 1] Train loss: 0.058, acc: 88.08, time: 139.7s
# [Epoch 1] Valid loss: 0.054, acc: 91.40
# [Epoch 2] Train loss: 0.022, acc: 95.78, time: 139.7s
# [Epoch 2] Valid loss: 0.055, acc: 91.00
# [Epoch 3] Train loss: 0.011, acc: 97.92, time: 139.7s
# [Epoch 3] Valid loss: 0.065, acc: 92.00
# [Epoch 4] Train loss: 0.006, acc: 98.96, time: 139.7s
# [Epoch 4] Valid loss: 0.071, acc: 90.20
# [Epoch 5] Train loss: 0.004, acc: 99.45, time: 139.7s
# [Epoch 5] Valid loss: 0.074, acc: 92.00
# [Epoch 6] Train loss: 0.002, acc: 99.87, time: 139.6s
# [Epoch 6] Valid loss: 0.084, acc: 91.40
# [Epoch 7] Train loss: 0.002, acc: 99.64, time: 139.7s
# [Epoch 7] Valid loss: 0.089, acc: 90.80
# [Epoch 8] Train loss: 0.002, acc: 99.81, time: 139.8s
# [Epoch 8] Valid loss: 0.088, acc: 90.40
# [Epoch 9] Train loss: 0.001, acc: 99.94, time: 139.6s
# [Epoch 9] Valid loss: 0.088, acc: 90.60
# Training finish! Best validation accuracy: 92.00
#
# Start trining 6th model
# [Epoch 0] Train loss: 0.126, acc: 59.87, time: 139.9s
# [Epoch 0] Valid loss: 0.067, acc: 87.40
# [Epoch 1] Train loss: 0.061, acc: 87.69, time: 139.7s
# [Epoch 1] Valid loss: 0.054, acc: 90.20
# [Epoch 2] Train loss: 0.023, acc: 95.55, time: 139.6s
# [Epoch 2] Valid loss: 0.077, acc: 90.40
# [Epoch 3] Train loss: 0.010, acc: 98.28, time: 139.6s
# [Epoch 3] Valid loss: 0.088, acc: 89.60
# [Epoch 4] Train loss: 0.006, acc: 99.03, time: 139.6s
# [Epoch 4] Valid loss: 0.091, acc: 90.00
# [Epoch 5] Train loss: 0.005, acc: 99.09, time: 139.6s
# [Epoch 5] Valid loss: 0.083, acc: 90.60
# [Epoch 6] Train loss: 0.002, acc: 99.71, time: 139.7s
# [Epoch 6] Valid loss: 0.099, acc: 90.20
# [Epoch 7] Train loss: 0.001, acc: 99.81, time: 139.6s
# [Epoch 7] Valid loss: 0.094, acc: 90.80
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 139.6s
# [Epoch 8] Valid loss: 0.099, acc: 90.80
# [Epoch 9] Train loss: 0.001, acc: 99.90, time: 139.6s
# [Epoch 9] Valid loss: 0.098, acc: 91.00
# Training finish! Best validation accuracy: 91.00
#
# Start trining 7th model
# [Epoch 0] Train loss: 0.117, acc: 63.77, time: 139.8s
# [Epoch 0] Valid loss: 0.063, acc: 89.00
# [Epoch 1] Train loss: 0.055, acc: 88.86, time: 139.5s
# [Epoch 1] Valid loss: 0.051, acc: 91.20
# [Epoch 2] Train loss: 0.021, acc: 95.88, time: 139.6s
# [Epoch 2] Valid loss: 0.058, acc: 90.80
# [Epoch 3] Train loss: 0.013, acc: 97.37, time: 139.5s
# [Epoch 3] Valid loss: 0.074, acc: 91.20
# [Epoch 4] Train loss: 0.007, acc: 98.83, time: 139.5s
# [Epoch 4] Valid loss: 0.077, acc: 91.20
# [Epoch 5] Train loss: 0.004, acc: 99.58, time: 139.5s
# [Epoch 5] Valid loss: 0.082, acc: 91.00
# [Epoch 6] Train loss: 0.002, acc: 99.77, time: 139.5s
# [Epoch 6] Valid loss: 0.084, acc: 91.80
# [Epoch 7] Train loss: 0.001, acc: 99.81, time: 139.5s
# [Epoch 7] Valid loss: 0.085, acc: 91.40
# [Epoch 8] Train loss: 0.001, acc: 99.90, time: 139.5s
# [Epoch 8] Valid loss: 0.091, acc: 91.40
# [Epoch 9] Train loss: 0.001, acc: 99.87, time: 139.5s
# [Epoch 9] Valid loss: 0.089, acc: 91.40
# Training finish! Best validation accuracy: 91.80
#
# Start trining 8th model
# [Epoch 0] Train loss: 0.123, acc: 60.78, time: 139.8s
# [Epoch 0] Valid loss: 0.065, acc: 86.40
# [Epoch 1] Train loss: 0.056, acc: 88.47, time: 139.5s
# [Epoch 1] Valid loss: 0.056, acc: 89.80
# [Epoch 2] Train loss: 0.023, acc: 95.81, time: 139.5s
# [Epoch 2] Valid loss: 0.066, acc: 89.20
# [Epoch 3] Train loss: 0.010, acc: 98.41, time: 139.5s
# [Epoch 3] Valid loss: 0.080, acc: 89.60
# [Epoch 4] Train loss: 0.006, acc: 99.06, time: 139.5s
# [Epoch 4] Valid loss: 0.080, acc: 90.80
# [Epoch 5] Train loss: 0.003, acc: 99.74, time: 139.5s
# [Epoch 5] Valid loss: 0.081, acc: 91.20
# [Epoch 6] Train loss: 0.001, acc: 99.84, time: 139.5s
# [Epoch 6] Valid loss: 0.086, acc: 91.60
# [Epoch 7] Train loss: 0.001, acc: 99.87, time: 139.5s
# [Epoch 7] Valid loss: 0.099, acc: 91.20
# [Epoch 8] Train loss: 0.001, acc: 99.97, time: 139.5s
# [Epoch 8] Valid loss: 0.093, acc: 91.80
# [Epoch 9] Train loss: 0.001, acc: 99.97, time: 139.5s
# [Epoch 9] Valid loss: 0.094, acc: 92.00
# Training finish! Best validation accuracy: 92.00
#
# Start trining 9th model
# [Epoch 0] Train loss: 0.118, acc: 64.09, time: 139.5s
# [Epoch 0] Valid loss: 0.064, acc: 88.00
# [Epoch 1] Train loss: 0.054, acc: 88.60, time: 139.7s
# [Epoch 1] Valid loss: 0.052, acc: 91.80
# [Epoch 2] Train loss: 0.021, acc: 96.04, time: 139.7s
# [Epoch 2] Valid loss: 0.072, acc: 90.40
# [Epoch 3] Train loss: 0.010, acc: 98.08, time: 139.6s
# [Epoch 3] Valid loss: 0.084, acc: 90.60
# [Epoch 4] Train loss: 0.005, acc: 99.19, time: 139.4s
# [Epoch 4] Valid loss: 0.083, acc: 90.40
# [Epoch 5] Train loss: 0.003, acc: 99.58, time: 139.4s
# [Epoch 5] Valid loss: 0.086, acc: 91.40
# [Epoch 6] Train loss: 0.002, acc: 99.71, time: 139.4s
# [Epoch 6] Valid loss: 0.090, acc: 90.60
# [Epoch 7] Train loss: 0.002, acc: 99.84, time: 139.4s
# [Epoch 7] Valid loss: 0.095, acc: 90.00
# [Epoch 8] Train loss: 0.001, acc: 99.84, time: 139.5s
# [Epoch 8] Valid loss: 0.090, acc: 91.20
# [Epoch 9] Train loss: 0.001, acc: 99.87, time: 139.5s
# [Epoch 9] Valid loss: 0.091, acc: 91.00
# Training finish! Best validation accuracy: 91.80

# %% [markdown]
# ## Test Models

# %%
def validate_ensemble(val_loader, answer, idx_max=10):
    pred_ensemble = []
    for idx in range(idx_max):
        model = Roberta.from_pretrained(os.path.join(save_dir, f'{idx}'), model_name)
        model.to(device)
        acc, pred_all = validate('best', model, val_loader, verbose=False)
        print(f"Load {idx}th model (acc: {acc*100:.2f})")
        if acc >= 0.85:
            pred_ensemble.append(pred_all)
        
    pred_ensemble = torch.stack(pred_ensemble, dim=-1).float()
    pred_ensemble = (pred_ensemble.mean(-1) >= 0.5).long().to(answer.device)
    acc_ensemble = (pred_ensemble == answer).sum() / len(answer)
    print(f"\nEnsemble accuracy: {acc_ensemble*100:.2f}")

# %%
answer = torch.tensor(val_dataset.labels)
validate_ensemble(val_loader, answer, idx_max=10)
# Out:
# Load 0th model (acc: 91.60)
# Load 1th model (acc: 92.00)
# Load 2th model (acc: 91.80)
# Load 3th model (acc: 91.20)
# Load 4th model (acc: 91.20)
# Load 5th model (acc: 92.00)
# Load 6th model (acc: 91.00)
# Load 7th model (acc: 91.80)
# Load 8th model (acc: 92.00)
# Load 9th model (acc: 91.80)
#
# Ensemble accuracy: 93.00
